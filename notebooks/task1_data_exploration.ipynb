# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))

from src.data_loader import *
from src.explorer import *

# %%
# !pip install openpyxl

df = load_unified()

reference = load_reference_codes()

impact = load_impact_links()
# Out:
# Requirement already satisfied: openpyxl in /home/welela/venv/lib/python3.12/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /home/welela/venv/lib/python3.12/site-packages (from openpyxl) (2.0.0)

# %%
dataset_summary(df)
# Out:
# ==================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 34 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   record_id            58 non-null     object
#  1   record_type          58 non-null     object
#  2   category             15 non-null     object
#  3   pillar               43 non-null     object
#  4   indicator            58 non-null     object
#  5   indicator_code       58 non-null     object
#  6   indicator_direction  43 non-null     object
#  7   value_numeric        43 non-null     float64
#  8   value_text           10 non-null     object
#  9   value_type           53 non-null     object
#  10  unit                 43 non-null     object
#  11  observation_date     58 non-null     datetime64[ns]
#  12  period_start         10 non-null     datetime64[ns]
#  13  period_end           10 non-null     datetime64[ns]
#  14  fiscal_year          53 non-null     object
#  15  gender               58 non-null     object
#  16  location             58 non-null     object
#  17  region               0 non-null      float64
#  18  source_name          58 non-null     object
#  19  source_type          58 non-null     object
#  20  source_url           46 non-null     object
#  21  confidence           58 non-null     object
#  22  related_indicator    0 non-null      float64
#  23  relationship_type    0 non-null      float64
#  24  impact_direction     0 non-null      float64
#  25  impact_magnitude     0 non-null      float64
#  26  impact_estimate      0 non-null      float64
#  27  lag_months           0 non-null      float64
#  28  evidence_basis       0 non-null      float64
#  29  comparable_country   0 non-null      float64
#  30  collected_by         58 non-null     object
#  31  collection_date      58 non-null     datetime64[ns]
#  32  original_text        25 non-null     object
#  33  notes                48 non-null     object
# dtypes: datetime64[ns](4), float64(10), object(20)
# memory usage: 15.5+ KB
# None
# ==================================================
#   record_id  record_type category  pillar               indicator  \
# 0  REC_0001  observation      NaN  ACCESS  Account Ownership Rate
# 1  REC_0002  observation      NaN  ACCESS  Account Ownership Rate
# 2  REC_0003  observation      NaN  ACCESS  Account Ownership Rate
# 3  REC_0004  observation      NaN  ACCESS  Account Ownership Rate
# 4  REC_0005  observation      NaN  ACCESS  Account Ownership Rate
#
#   indicator_code indicator_direction  value_numeric value_text  value_type  \
# 0  ACC_OWNERSHIP       higher_better           22.0        NaN  percentage
# 1  ACC_OWNERSHIP       higher_better           35.0        NaN  percentage
# 2  ACC_OWNERSHIP       higher_better           46.0        NaN  percentage
# 3  ACC_OWNERSHIP       higher_better           56.0        NaN  percentage
# 4  ACC_OWNERSHIP       higher_better           36.0        NaN  percentage
#
#    ... impact_direction impact_magnitude impact_estimate lag_months  \
# 0  ...              NaN              NaN             NaN        NaN
# 1  ...              NaN              NaN             NaN        NaN
# 2  ...              NaN              NaN             NaN        NaN
# 3  ...              NaN              NaN             NaN        NaN
# 4  ...              NaN              NaN             NaN        NaN
#
#   evidence_basis comparable_country     collected_by  collection_date  \
# 0            NaN                NaN  Example_Trainee       2025-01-20
# 1            NaN                NaN  Example_Trainee       2025-01-20
# 2            NaN                NaN  Example_Trainee       2025-01-20
# 3            NaN                NaN  Example_Trainee       2025-01-20
# 4            NaN                NaN  Example_Trainee       2025-01-20
#
#   original_text                 notes
# 0           NaN         Baseline year
# 1           NaN                   NaN
# 2           NaN                   NaN
# 3           NaN  Gender disaggregated
# 4           NaN  Gender disaggregated
#
# [5 rows x 34 columns]
# ==================================================
#        record_id  record_type category  pillar               indicator  \
# count         58           58       15      43                      58
# unique        58            3        7       4                      42
# top     REC_0001  observation   policy  ACCESS  Account Ownership Rate
# freq           1           40        6      25                       9
# mean         NaN          NaN      NaN     NaN                     NaN
# min          NaN          NaN      NaN     NaN                     NaN
# 25%          NaN          NaN      NaN     NaN                     NaN
# 50%          NaN          NaN      NaN     NaN                     NaN
# 75%          NaN          NaN      NaN     NaN                     NaN
# max          NaN          NaN      NaN     NaN                     NaN
# std          NaN          NaN      NaN     NaN                     NaN
#
#        indicator_code indicator_direction  value_numeric value_text  \
# count              58                  43   4.300000e+01         10
# unique             42                   3            NaN          3
# top     ACC_OWNERSHIP       higher_better            NaN   Launched
# freq                9                  36            NaN          7
# mean              NaN                 NaN   7.242547e+10        NaN
# min               NaN                 NaN   1.080000e+00        NaN
# 25%               NaN                 NaN   2.300000e+01        NaN
# 50%               NaN                 NaN   5.600000e+01        NaN
# 75%               NaN                 NaN   9.400000e+06        NaN
# max               NaN                 NaN   2.380000e+12        NaN
# std               NaN                 NaN   3.715140e+11        NaN
#
#         value_type  ... impact_direction impact_magnitude impact_estimate  \
# count           53  ...              0.0              0.0             0.0
# unique           6  ...              NaN              NaN             NaN
# top     percentage  ...              NaN              NaN             NaN
# freq            25  ...              NaN              NaN             NaN
# mean           NaN  ...              NaN              NaN             NaN
# min            NaN  ...              NaN              NaN             NaN
# 25%            NaN  ...              NaN              NaN             NaN
# 50%            NaN  ...              NaN              NaN             NaN
# 75%            NaN  ...              NaN              NaN             NaN
# max            NaN  ...              NaN              NaN             NaN
# std            NaN  ...              NaN              NaN             NaN
#
#        lag_months  evidence_basis comparable_country     collected_by  \
# count         0.0             0.0                0.0               58
# unique        NaN             NaN                NaN                2
# top           NaN             NaN                NaN  Example_Trainee
# freq          NaN             NaN                NaN               43
# mean          NaN             NaN                NaN              NaN
# min           NaN             NaN                NaN              NaN
# 25%           NaN             NaN                NaN              NaN
# 50%           NaN             NaN                NaN              NaN
# 75%           NaN             NaN                NaN              NaN
# max           NaN             NaN                NaN              NaN
# std           NaN             NaN                NaN              NaN
#
#                       collection_date  \
# count                              58
# unique                            NaN
# top                               NaN
# freq                              NaN
# mean    2025-06-09 22:45:31.034482688
# min               2025-01-20 00:00:00
# 25%               2025-01-20 00:00:00
# 50%               2025-01-20 00:00:00
# 75%               2026-03-04 18:00:00
# max               2026-07-19 00:00:00
# std                               NaN
#
#                                       original_text                 notes
# count                                            25                    48
# unique                                           25                    47
# top     Account ownership increased from 46% to 49%  Gender disaggregated
# freq                                              1                     2
# mean                                            NaN                   NaN
# min                                             NaN                   NaN
# 25%                                             NaN                   NaN
# 50%                                             NaN                   NaN
# 75%                                             NaN                   NaN
# max                                             NaN                   NaN
# std                                             NaN                   NaN
#
# [11 rows x 34 columns]

# %%
record_counts(df)
# Out:
#  record_type
# record_type
# observation    40
# event          15
# target          3
# Name: count, dtype: int64
#
#  pillar
# pillar
# ACCESS           25
# NaN              15
# USAGE            12
# GENDER            5
# AFFORDABILITY     1
# Name: count, dtype: int64
#
#  source_type
# source_type
# operator      15
# survey        12
# research      12
# regulator     10
# policy         5
# calculated     2
# news           2
# Name: count, dtype: int64
#
#  confidence
# confidence
# high      48
# medium    10
# Name: count, dtype: int64

# %%
temporal_range(df)
# Out:
# Start: 2014-12-31 00:00:00
# End: 2030-12-31 00:00:00

# %%
indicator_coverage(df)
# Out:
# indicator_code         indicator
# ACC_4G_COV             4G Population Coverage                                                                        2
# ACC_ATM_DENSITY        ATMs per 100,000 Adults                                                                       1
# ACC_BANK_BRANCH        Commercial Bank Branches per 100,000 Adults                                                   1
# ACC_FAYDA              Fayda Digital ID Enrollment                                                                   4
# ACC_INTERNET_PEN       Internet Penetration Rate (Individuals Using the Internet)                                    1
# ACC_MM_ACCOUNT         Mobile Money Account Rate                                                                     2
# ACC_MOBILE_PEN         Mobile Subscription Penetration                                                               1
# ACC_OWNERSHIP          Account Ownership Rate                                                                        9
# ACC_OWNERSHIP_EDU_SEC  Account Ownership Rate - Secondary+ Education                                                 1
# ACC_OWNERSHIP_SELFEMP  Account Ownership Rate - Self-Employed                                                        1
# ACC_OWNERSHIP_URBAN    Account Ownership Rate - Urban                                                                1
# ACC_OWNERSHIP_WAGE     Account Ownership Rate - Wage Workers                                                         1
# AFF_DATA_INCOME        Data Affordability Index                                                                      1
# EVT_CROSSOVER          P2P Transaction Count Surpasses ATM                                                           1
# EVT_ESX                Ethiopian Securities Exchange (ESX) Official Launch                                           1
# EVT_ETHIOPAY           EthioPay Instant Payment System Launch                                                        1
# EVT_FAYDA              Fayda Digital ID Program Rollout                                                              1
# EVT_FOREIGN_BANK       Banking Business Proclamation No. 1360/2024 (Foreign Banks Permitted)                         1
# EVT_FX_REFORM          Foreign Exchange Liberalization                                                               1
# EVT_MPESA              M-Pesa Ethiopia Launch                                                                        1
# EVT_MPESA_INTEROP      M-Pesa EthSwitch Integration                                                                  1
# EVT_NFIS1              NFIS-I: First National Financial Inclusion Strategy Launch                                    1
# EVT_NFIS2              NFIS-II Strategy Launch                                                                       1
# EVT_PII_AMEND2023      Payment Instrument Issuer Amendment Directive No. ONPS/09/2023 (Raised Transaction Limits)    1
# EVT_PII_DIRECTIVE      Payment Instrument Issuers Directive No. ONPS/01/2020 (Mobile Money Licensing Framework)      1
# EVT_SAFARICOM          Safaricom Ethiopia Commercial Launch                                                          1
# EVT_SAFCOM_PRICE       Safaricom Ethiopia Price Increase                                                             1
# EVT_TELEBIRR           Telebirr Launch                                                                               1
# GEN_GAP_ACC            Account Ownership Gender Gap                                                                  2
# GEN_GAP_MOBILE         Mobile Phone Gender Gap                                                                       1
# GEN_MM_SHARE           Female Mobile Money Account Share                                                             2
# USG_ACTIVE_RATE        Mobile Money Activity Rate                                                                    1
# USG_ATM_COUNT          ATM Transaction Count                                                                         1
# USG_ATM_VALUE          ATM Transaction Value                                                                         1
# USG_BARRIER_NOPHONE    Adults Citing No Mobile Phone as Barrier to Mobile Money                                      1
# USG_CROSSOVER          P2P/ATM Crossover Ratio                                                                       1
# USG_MPESA_ACTIVE       M-Pesa 90-Day Active Users                                                                    1
# USG_MPESA_USERS        M-Pesa Registered Users                                                                       1
# USG_P2P_COUNT          P2P Transaction Count                                                                         2
# USG_P2P_VALUE          P2P Transaction Value                                                                         1
# USG_TELEBIRR_USERS     Telebirr Registered Users                                                                     1
# USG_TELEBIRR_VALUE     Telebirr Transaction Value                                                                    1
# dtype: int64

# %%
events(df)
# Out:
#    record_id        category  \
# 33  EVT_0001  product_launch
# 34  EVT_0002    market_entry
# 35  EVT_0003  product_launch
# 36  EVT_0004  infrastructure
# 37  EVT_0005          policy
# 38  EVT_0006       milestone
# 39  EVT_0007     partnership
# 40  EVT_0008  infrastructure
# 41  EVT_0009          policy
# 42  EVT_0010         pricing
# 53  EVT_0011          policy
# 54  EVT_0012          policy
# 55  EVT_0013          policy
# 56  EVT_0014          policy
# 57  EVT_0015  infrastructure
#
#                                             indicator observation_date  \
# 33                                    Telebirr Launch       2021-05-17
# 34               Safaricom Ethiopia Commercial Launch       2022-08-01
# 35                             M-Pesa Ethiopia Launch       2023-08-01
# 36                   Fayda Digital ID Program Rollout       2024-01-01
# 37                    Foreign Exchange Liberalization       2024-07-29
# 38                P2P Transaction Count Surpasses ATM       2024-10-01
# 39                       M-Pesa EthSwitch Integration       2025-10-27
# 40             EthioPay Instant Payment System Launch       2025-12-18
# 41                            NFIS-II Strategy Launch       2021-09-01
# 42                  Safaricom Ethiopia Price Increase       2025-12-15
# 53  NFIS-I: First National Financial Inclusion Str...       2017-10-01
# 54  Payment Instrument Issuers Directive No. ONPS/...       2020-04-01
# 55  Payment Instrument Issuer Amendment Directive ...       2023-10-06
# 56  Banking Business Proclamation No. 1360/2024 (F...       2024-12-17
# 57  Ethiopian Securities Exchange (ESX) Official L...       2025-01-10
#
#                                          source_name confidence
# 33                                     Ethio Telecom       high
# 34                                              News       high
# 35                                         Safaricom       high
# 36                                              NIDP       high
# 37                                               NBE       high
# 38                                         EthSwitch       high
# 39                                         EthSwitch       high
# 40                                     NBE/EthSwitch       high
# 41                                               NBE       high
# 42                                              News       high
# 53            National Bank of Ethiopia / World Bank       high
# 54                         National Bank of Ethiopia       high
# 55                         National Bank of Ethiopia       high
# 56  Ethiopian Parliament / National Bank of Ethiopia       high
# 57          Ethiopian Capital Market Authority / ESX       high

# %%
print(df.columns.tolist())
# Out:
# ['record_id', 'record_type', 'category', 'pillar', 'indicator', 'indicator_code', 'indicator_direction', 'value_numeric', 'value_text', 'value_type', 'unit', 'observation_date', 'period_start', 'period_end', 'fiscal_year', 'gender', 'location', 'region', 'source_name', 'source_type', 'source_url', 'confidence', 'related_indicator', 'relationship_type', 'impact_direction', 'impact_magnitude', 'impact_estimate', 'lag_months', 'evidence_basis', 'comparable_country', 'collected_by', 'collection_date', 'original_text', 'notes']
