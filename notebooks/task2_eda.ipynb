# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))


import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import matplotlib.pyplot as plt

from src.eda import *

# %%
df = pd.read_excel("../data/raw/ethiopia_fi_unified_data_enriched.xlsx",sheet_name=1)

print(df.shape)

df.head()
# Out:
# (58, 34)
#   record_id  record_type category  pillar               indicator  \
# 0  REC_0001  observation      NaN  ACCESS  Account Ownership Rate
# 1  REC_0002  observation      NaN  ACCESS  Account Ownership Rate
# 2  REC_0003  observation      NaN  ACCESS  Account Ownership Rate
# 3  REC_0004  observation      NaN  ACCESS  Account Ownership Rate
# 4  REC_0005  observation      NaN  ACCESS  Account Ownership Rate
#
#   indicator_code indicator_direction  value_numeric value_text  value_type  \
# 0  ACC_OWNERSHIP       higher_better           22.0        NaN  percentage
# 1  ACC_OWNERSHIP       higher_better           35.0        NaN  percentage
# 2  ACC_OWNERSHIP       higher_better           46.0        NaN  percentage
# 3  ACC_OWNERSHIP       higher_better           56.0        NaN  percentage
# 4  ACC_OWNERSHIP       higher_better           36.0        NaN  percentage
#
#    ... impact_direction impact_magnitude impact_estimate lag_months  \
# ...

# %%
dataset_summary(df)
# Out:
# ...
# Dataset Shape
# (58, 34)
#
# Columns
# ['record_id', 'record_type', 'category', 'pillar', 'indicator', 'indicator_code', 'indicator_direction', 'value_numeric', 'value_text', 'value_type', 'unit', 'observation_date', 'period_start', 'period_end', 'fiscal_year', 'gender', 'location', 'region', 'source_name', 'source_type', 'source_url', 'confidence', 'related_indicator', 'relationship_type', 'impact_direction', 'impact_magnitude', 'impact_estimate', 'lag_months', 'evidence_basis', 'comparable_country', 'collected_by', 'collection_date', 'original_text', 'notes']
#
# Data Types
# record_id                      object
# record_type                    object
# category                       object
# pillar                         object
# indicator                      object
# indicator_code                 object
# indicator_direction            object
# value_numeric                 float64
# value_text                     object
# value_type                     object
# ...

# %%
plot_record_types(df)

# %%
plot_pillars(df)

# %%
plot_source_types(df)

# %%
plot_confidence(df)

# %%
temporal_coverage(df)

# %%
indicator_coverage(df)
# Out:
# indicator
# Account Ownership Rate                                        8
# Fayda Digital ID Enrollment                                   3
# Account Ownership Gender Gap                                  2
# Mobile Money Account Rate                                     2
# P2P Transaction Count                                         2
# 4G Population Coverage                                        2
# ATM Transaction Value                                         1
# Account Ownership Rate - Self-Employed                        1
# ATM Transaction Count                                         1
# ATMs per 100,000 Adults                                       1
# Account Ownership Rate - Secondary+ Education                 1
# Adults Citing No Mobile Phone as Barrier to Mobile Money      1
# Account Ownership Rate - Wage Workers                         1
# Account Ownership Rate - Urban                                1
# ...

# %%
quality = data_quality_report(df)

quality.head()
# Out:
#                      missing           dtype
# record_id                  0          object
# record_type                0          object
# category                  43          object
# pillar                    15          object
# indicator                  0          object
# indicator_code             0          object
# indicator_direction       15          object
# value_numeric             15         float64
# value_text                48          object
# value_type                 5          object
# unit                      15          object
# observation_date           0  datetime64[ns]
# period_start              48  datetime64[ns]
# period_end                48  datetime64[ns]
# fiscal_year                5          object
# gender                     0          object
# location                   0          object
# region                    58         float64
# source_name                0          object
# source_type                0          object
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# lag_months             58
# region                 58
# impact_estimate        58
# relationship_type      58
# evidence_basis         58
# comparable_country     58
# related_indicator      58
# impact_magnitude       58
# impact_direction       58
# value_text             48
# period_end             48
# period_start           48
# category               43
# original_text          33
# pillar                 15
# unit                   15
# indicator_direction    15
# value_numeric          15
# source_url             12
# notes                  10
# fiscal_year             5
# value_type              5
# record_type             0
# record_id               0
# indicator_code          0
# indicator               0
# location                0
# gender                  0
# observation_date        0
# confidence              0
# source_type             0
# source_name             0
# collection_date         0
# collected_by            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
account_ownership(df)
# Out:
# Growth (Percentage Points)
# year
# 2014          NaN
# 2017    13.000000
# 2021     6.671429
# 2024     1.022321
# Name: value_numeric, dtype: float64

# %%
gender_gap(df)

# %%
urban = df[df["location"]=="Urban"]

rural = df[df["location"]=="Rural"]

urban.head()

rural.head()
# Out:
# Empty DataFrame
# Columns: [record_id, record_type, category, pillar, indicator, indicator_code, indicator_direction, value_numeric, value_text, value_type, unit, observation_date, period_start, period_end, fiscal_year, gender, location, region, source_name, source_type, source_url, confidence, related_indicator, relationship_type, impact_direction, impact_magnitude, impact_estimate, lag_months, evidence_basis, comparable_country, collected_by, collection_date, original_text, notes]
# Index: []
#
# [0 rows x 34 columns]

# %%
mobile_money(df)

# %%
infrastructure(df)
# Out:
#                                             indicator  value_numeric  \
# 6                           Mobile Money Account Rate   4.700000e+00
# 7                           Mobile Money Account Rate   9.450000e+00
# 8                              4G Population Coverage   3.750000e+01
# 9                              4G Population Coverage   7.080000e+01
# 10                    Mobile Subscription Penetration   6.140000e+01
# 17                              ATM Transaction Count   1.193000e+08
# 18                              ATM Transaction Value   1.561000e+11
# 19                            P2P/ATM Crossover Ratio   1.080000e+00
# 24                         Mobile Money Activity Rate   6.600000e+01
# 28                  Female Mobile Money Account Share   1.400000e+01
# 29                            Mobile Phone Gender Gap   2.400000e+01
# 49  Adults Citing No Mobile Phone as Barrier to Mo...   5.100000e+01
# 51                            ATMs per 100,000 Adults   1.007000e+01
# ...

# %%
event_timeline(df)

# %%
corr = correlation_matrix(df)

corr
# Out:
# indicator_code         ACC_4G_COV  ACC_ATM_DENSITY  ACC_BANK_BRANCH  \
# indicator_code
# ACC_4G_COV                    1.0              NaN              NaN
# ACC_ATM_DENSITY               NaN              NaN              NaN
# ACC_BANK_BRANCH               NaN              NaN              NaN
# ACC_FAYDA                     NaN              NaN              NaN
# ACC_INTERNET_PEN              NaN              NaN              NaN
# ACC_MM_ACCOUNT                NaN              NaN              NaN
# ACC_MOBILE_PEN                NaN              NaN              NaN
# ACC_OWNERSHIP                 NaN              NaN              NaN
# ACC_OWNERSHIP_EDU_SEC         NaN              NaN              NaN
# ACC_OWNERSHIP_SELFEMP         NaN              NaN              NaN
# ACC_OWNERSHIP_URBAN           NaN              NaN              NaN
# ACC_OWNERSHIP_WAGE            NaN              NaN              NaN
# AFF_DATA_INCOME               NaN              NaN              NaN
# ...
